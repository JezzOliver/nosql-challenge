# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'epa', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('64681b9239a784f34ce5e047'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 1.195625, 'latitude': 51.083812}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}], 'longitude': None, 'latitude': None}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
Penang_Flavours = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(Penang_Flavours)

# %%
# Check that the new restaurant was inserted
query = {'BusinessName': "Penang Flavours"}
print("Number of documents in result:", establishments.count_documents(query))
# Out:
# Number of documents in result: 7

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e047')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e048')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e049')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e04e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e04f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e050')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e051')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e052')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e053')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e054')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e055')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e056')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e057')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e058')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e059')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('64681b9239a784f34ce5e05a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e05b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e05c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e05d')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e05e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e05f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e060')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e061')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e062')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e063')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e064')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e065')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e066')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e067')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('64681b9239a784f34ce5e068')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('64681b9239a784f34ce5e069')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e06a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e06c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e06d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e06e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e06f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e070')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e071')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e072')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e074')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e075')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e076')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e077')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e078')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e079')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e07a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e07b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e07d')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('64681b9239a784f34ce5e07f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e080')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e082')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e084')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e085')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e086')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e088')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e089')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e08a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e08b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e08c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e08d')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e08f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e090')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e091')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e093')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e095')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e096')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e098')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e099')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e09a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e09b')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e09c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e09d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e09e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e09f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0a0')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0a1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0a2')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0a4')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e0a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0a6')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e0a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0a9')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e0aa')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0ad')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('64681b9239a784f34ce5e0ae')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e0af')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0b1')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0b2')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0b3')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e0b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0b6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0b7')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0b9')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0bd')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0bf')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0c0')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0c2')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('64681b9239a784f34ce5e0c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0c4')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0c5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0c6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0c8')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0c9')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0cb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0cc')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0cd')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0cf')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0d0')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0d1')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0d2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0d3')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0d5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0d7')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0d8')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0da')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0dc')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e0dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0df')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0e1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0e2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0e4')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0e7')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0e8')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e0e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0ea')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0eb')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0ec')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0f0')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0f3')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e0f4')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e0f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0f6')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0f7')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0f9')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e0fa')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e0fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0fd')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e0fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e0ff')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e100')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e101')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e103')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e104')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e105')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e106')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e107')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e108')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e109')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e10a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e10b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e10c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e10d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e10f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e110')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e111')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e112')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e113')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e114')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e115')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e116')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e117')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e118')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e119')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e11a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e11b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e11c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e11d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e11e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e11f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e120')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e121')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e122')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e123')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e124')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e125')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e126')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e127')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e128')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e129')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e12a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e12b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e12c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e12d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e12e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e12f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e130')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e131')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e132')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e133')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e134')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e135')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e136')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e137')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e138')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e139')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('64681b9239a784f34ce5e13a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e13b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e13c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e13d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e13e')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e13f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e140')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e141')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e142')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e143')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e144')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e145')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e146')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e147')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e148')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e149')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e14a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e14b')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('64681b9239a784f34ce5e14c')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e14d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e14e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e14f')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e150')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e151')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e152')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e153')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e154')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e155')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e156')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e157')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e158')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e159')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e15a')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e15b')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e15c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e15d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e15e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e15f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e161')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e162')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e163')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e164')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e165')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e166')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e167')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e168')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e169')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e16a')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e16b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e16c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e16d')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e16e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e16f')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e170')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e171')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e172')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e173')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e174')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e175')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e176')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e177')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e178')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e179')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e17a')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e17b')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e17c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e17d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e17e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e17f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e180')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e181')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e182')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e183')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e184')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e186')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e188')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e189')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e18a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e18b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e18c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e18d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e18e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e18f')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e190')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e191')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e192')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e193')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('64681b9239a784f34ce5e194')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e195')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e196')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e197')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e198')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e19a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e19b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e19c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e19d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e19e')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e19f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1a1')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1a2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1a3')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1a9')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1aa')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e1ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1ad')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e1af')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e1b0')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e1b2')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1b4')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1b6')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e1b9')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e1ba')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1bd')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9239a784f34ce5e1be')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1bf')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1c0')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1c1')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9239a784f34ce5e1c2')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1c3')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e1c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1c5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e1c6')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1c7')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1c9')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1cb')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1cd')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1ce')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1cf')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1d0')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e1d1')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1d2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1d3')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1d5')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1d6')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9239a784f34ce5e1d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1d9')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1da')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1dc')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1dd')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1de')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1e8')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1e9')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1ea')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e1eb')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1ec')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1ed')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e1ee')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1ef')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1f3')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e1f5')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e1f6')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e1f8')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e1f9')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e1fa')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e1fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e1ff')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e200')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e201')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e202')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e203')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e204')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e205')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e207')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e208')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e209')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e20a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e20b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e20c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e20d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e20e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e20f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e210')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9239a784f34ce5e211')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9239a784f34ce5e212')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9239a784f34ce5e213')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e214')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e215')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e216')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e217')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e218')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e219')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e21a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9239a784f34ce5e21b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e21c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e21d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e21e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9239a784f34ce5e21f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
# ...
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9339a784f34ce6460c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6460d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6460e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6460f')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9339a784f34ce64610')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64611')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64612')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64613')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64614')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9339a784f34ce64615')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64616')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64617')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64618')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64619')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce6461a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6461b')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9339a784f34ce6461c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce6461d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6461e')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9339a784f34ce6461f')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9339a784f34ce64620')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64621')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64622')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64623')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64624')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9339a784f34ce64625')}
# {'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('64681b9339a784f34ce64626')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64627')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64628')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64629')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce6462a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6462b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6462c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6462d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce6462e')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9339a784f34ce6462f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64630')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64631')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64632')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64633')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64634')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9339a784f34ce64635')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64636')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64637')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64638')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64639')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce6463a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6463b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6463c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6463d')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9339a784f34ce6463e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6463f')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64640')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64641')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64642')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64643')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64644')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9339a784f34ce64645')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64646')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64647')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64648')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('64681b9339a784f34ce64649')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6464a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6464b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6464c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6464d')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce6464e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6464f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64650')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64651')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64652')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64653')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64654')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64655')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64656')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64657')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64658')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9339a784f34ce64659')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('64681b9339a784f34ce6465a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce6465b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6465c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6465d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6465e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce6465f')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64660')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64661')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64662')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('64681b9339a784f34ce64663')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64664')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64665')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce64666')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64667')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64668')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64669')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6466a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6466b')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6466c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('64681b9339a784f34ce6466d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6466e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce6466f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64670')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64671')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64672')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64673')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64674')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64675')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64676')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64677')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64678')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64679')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6467a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6467b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6467c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6467d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6467e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6467f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64680')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64681')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64682')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64683')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64684')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64685')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64686')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64687')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64688')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64689')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce6468a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce6468b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6468c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce6468d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce6468e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce6468f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64690')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64681b9339a784f34ce64691')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64692')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64693')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('64681b9339a784f34ce64694')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('64681b9339a784f34ce64695')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64696')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('64681b9339a784f34ce64697')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('64681b9339a784f34ce64698')}
# {'BusinessType':
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one(
    {'BusinessName': 'Penang Flavours'},
    {'$set':
        {'BusinessTypeID': 1}
     }
)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1, 'BusinessName': 1}

# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
for result in results:
    pprint(result)
# Out:
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64682d305d69d926acc42a89')}
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('646a20463658c306b69e5001')}
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('646c9b7b7d6788551b0f32ba')}
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('646e002f94ffbe52477c303e')}
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('646e00bd8fc6092e4725f626')}
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('646e010de8f63a364e4a98ce')}
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('6470b0d2f7f08f85b0b55186')}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': "Dover"}
print("Number of documents in result:", establishments.count_documents(query))
# Out:
# Number of documents in result: 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': "Dover"}
print("Number of documents in result:", establishments.count_documents(query))
# Out:
# Number of documents in result: 0

# %%
# Check that other documents remain with 'find_one'
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('64681b9239a784f34ce5e047'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 1.195625, 'latitude': 51.083812}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}], 'longitude': None, 'latitude': None}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDouble': "$geocode.longitude"}}} ])

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDouble': "$geocode.latitude"}}} ])

# %%
#rating value to integer, must deal with null
establishments.update_many({}, [ {'$set':{'RatingValue': {'$convert': {'input': '$RatingValue', 'to': 'int', 'onError': 'null', 'onNull': 'null'}}}}])

# %%
# # Check that the coordinates are now numbers
query = {}
fields = {'BusinessName': 1, 'geocode.longitude': 1, 'geocode.latitude': 1, 'RatingValue': 1}
search = establishments.find(query, fields)

# Pretty print the first four results
for i in range(4):
     pprint(search[i])
# Out:
# {'BusinessName': 'The Pavilion',
#  'RatingValue': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e047'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'BusinessName': 'Wear Bay Bowls Club',
#  'RatingValue': 4,
#  '_id': ObjectId('64681b9239a784f34ce5e048'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'BusinessName': 'St Marys COE (aided) Primary School',
#  'RatingValue': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e049'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
# {'BusinessName': 'The Ship',
#  'RatingValue': 5,
#  '_id': ObjectId('64681b9239a784f34ce5e04e'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
